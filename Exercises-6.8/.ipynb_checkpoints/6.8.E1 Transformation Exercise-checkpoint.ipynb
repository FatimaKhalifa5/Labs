# %% [markdown]
# <img src="../assets/ga-logo.png" style="float: left; margin: 20px; height: 55px">
#
# # Exercise - `pandas` Data Transformation
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# ## Part A: Load and Clean

# %% [markdown]
# #### 1. Load `College.csv`
#
# - The first column doesn't have an accurate name, rename it.

# %%
# Your code here
df= pd.read_csv('./data/College.csv')
df.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#   PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0  70        78       18.1           12    7041         60
# 1  29        30       12.2           16   10527         56
# 2  53        66       12.9           30    8735         54
# 3  92        97        7.7           37   19016         59
# 4  76        72       11.9            2   10922         15

# %%
df.rename(columns={df.columns[0]: 'College'}, inplace=True)

df.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#   PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0  70        78       18.1           12    7041         60
# 1  29        30       12.2           16   10527         56
# 2  53        66       12.9           30    8735         54
# 3  92        97        7.7           37   19016         59
# 4  76        72       11.9            2   10922         15

# %% [markdown]
# #### 2. Check the shape, the data types of each column, and the number of missing values per column

# %%
# Your code here
df.shape
# Out:
# (777, 19)

# %%
df.dtypes
# Out:
# College            str
# Private            str
# Apps             int64
# Accept           int64
# Enroll           int64
# Top10perc        int64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal         int64
# PhD                str
# Terminal         int64
# S.F.Ratio      float64
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# College        0
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# dtype: int64

# %% [markdown]
# #### 3. Fix the `PhD` column
#
# - `PhD` is the percentage of faculty with a PhD, but it has inaccurate entries.
# - Fix the column and fill these entries with the plausible values.

# %%
# Your code here
df['PhD'].value_counts()
# Out:
# PhD
# ?      29
# 77     26
# 73     24
# 90     22
# 71     21
#        ..
# 32      1
# 14      1
# 103     1
# 26      1
# 16      1
# Name: count, Length: 78, dtype: int64

# %%
# Replace invalid values with NaN
df['PhD'] = df['PhD'].replace('?', np.nan)

# Convert to numeric
df['PhD'] = pd.to_numeric(df['PhD'])

# Replace values greater than 100 with NaN
df.loc[df['PhD'] > 100, 'PhD'] = np.nan

# Fill missing values with the median
df['PhD'] = df['PhD'].fillna(df['PhD'].median())

# Check the result
df['PhD'].value_counts()
# Out:
# PhD
# 75.0    51
# 77.0    26
# 73.0    24
# 90.0    22
# 71.0    21
#         ..
# 34.0     1
# 32.0     1
# 14.0     1
# 26.0     1
# 16.0     1
# Name: count, Length: 76, dtype: int64

# %%
df['PhD'].dtype
# Out:
# dtype('float64')

# %%
df['PhD']
# Out:
# 0      70.0
# 1      29.0
# 2      53.0
# 3      92.0
# 4      76.0
#        ...
# 772    60.0
# 773    73.0
# 774    67.0
# 775    96.0
# 776    75.0
# Name: PhD, Length: 777, dtype: float64

# %% [markdown]
# #### 4. Fix the `Grad.Rate` column
#
# - `Grad.Rate` is the graduation rate, but it has data entry errors.

# %%
# Your code here
df[df['Grad.Rate'] > 100]
# Out:
#               College Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# 95  Cazenovia College     Yes  3847    3433     527          9         35
#
#     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal   PhD  \
# 95         1010           12      9384        4840    600       500  22.0
#
#     Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 95        47       14.3           20    7697        118

# %%
# Replace graduation rates above 100 with 100
df.loc[df['Grad.Rate'] > 100, 'Grad.Rate'] = 100
df[df['Grad.Rate'] > 100]
# Out:
# Empty DataFrame
# Columns: [College, Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %% [markdown]
# ## Part B: Diagnose, Transform, and Visualize Skew

# %% [markdown]
# #### The tables bellow can be used as a reference to classify the the degree and distribution of the skewness as well as the right distribution transformation method.

# %% [markdown]
# ### Table1: Skewness Score Interpretation
#
# | Skewness Score Range | Distribution Shape |
# | :--- | :--- |
# | **Less than -1** | Highly Skewed (Left) |
# | **Between -1 and -0.5** | Moderately Skewed (Left) |
# | **Between -0.5 and 0.5** | `Normal (Symmetrical)` |
# | **Between 0.5 and 1** | Moderately Skewed (Right) |
# | **Greater than 1** | Highly Skewed (Right) |

# %% [markdown]
# ### Table2: Decision Matrix: Choosing the Right Distribution Transformation
#
# | Transformation | Best Data Shape / Scenario | Handles Zeros? | Handles Negatives? | Impact on Linear Models / Interpretability |
# | :--- | :--- | :--- | :--- | :--- |
# | **Log Plus One ($\log(x+1)$)** | Highly Right-Skewed with zero counts |  Yes | ❌ No | Safely maps zero values to zero while retaining standard log-compression benefits. |
# | **Box-Cox** | Right or Left Skewed (Strictly positive) | ❌ No | ❌ No | Automatically searches for the mathematically ideal power exponent ($\lambda$) to maximize normality. |
# | **Yeo-Johnson** | Right or Left Skewed (Versatile) |  Yes |  Yes | Modifies the Box-Cox algorithm to safely calculate ideal power scales across zeros and negatives. |

# %% [markdown]
# #### 5. Write `skew_calc()` with `%%writefile`, then `plot_transformations()` here
#
# - `skew_calc(df)`: for every numeric column, calculate its skewness, classify the degree and direction, and recommend a transformation. Use `%%writefile` to save this into `myutils.py`, then import it.
# - `plot_transformations(df, skew_table)`: take a DataFrame together with the output of `skew_calc()`, apply the **best** recommended transformation to each column, and plot the before and after distributions side by side with the skewness labeled on each subplot.

# %%
# %%writefile myutils.py
import numpy as np
import pandas as pd

def skew_calc(df):
    """
    Diagnoses skewness for every numeric column in a DataFrame and recommends a transformation based on the column's skewness and
    minimum value. Binary, encoded, and ID columns are excluded, since skewness isn't a meaningful for them.
    It returns a DataFrame with the following columns:
    Feature, Skewness, Degree, Direction, Recommended Transformation
    """
    # Your code here 

    results = []

    # Select numeric columns only
    numeric_columns = df.select_dtypes(include=np.number).columns

    # Skip binary indicators (0/1) or columns ending with '_id'
    if 'id' in str(col).lower() or df[col].nunique() <= 2:
            continue

    for column in numeric_columns:

        # Skip binary columns
        if df[column].nunique() <= 2:
            continue

        skewness = df[column].skew()
        minimum = df[column].min()

        

        # Classify degree and direction
        if skewness < -1:
            degree = 'Highly Skewed'
            direction = 'Left'

        elif -1 <= skewness < -0.5:
            degree = 'Moderately Skewed'
            direction = 'Left'

        elif -0.5 <= skewness <= 0.5:
            degree = 'Normal'
            direction = 'Symmetrical'

        elif 0.5 < skewness <= 1:
            degree = 'Moderately Skewed'
            direction = 'Right'

        else:
            degree = 'Highly Skewed'
            direction = 'Right'

        # Recommend transformation
        if -0.5 <= skewness <= 0.5:
            transformation = 'None'

        elif minimum < 0:
            transformation = 'Yeo-Johnson'

        elif minimum == 0 and skewness > 1:
            transformation = 'Log Plus One'

        elif minimum > 0:
            transformation = 'Box-Cox'

        else:
            transformation = 'Yeo-Johnson'

        results.append({
            'Feature': column,
            'Skewness': skewness,
            'Degree': degree,
            'Direction': direction,
            'Recommended Transformation': transformation
        })

    return pd.DataFrame(results)
# Out:
# Overwriting myutils.py

# %%
# Now import the function from myutils
from myutils import skew_calc

# %%
skew_table = skew_calc(df)

skew_table
# Out:
#         Feature  Skewness             Degree    Direction  \
# 0          Apps  3.723750      Highly Skewed        Right
# 1        Accept  3.417727      Highly Skewed        Right
# 2        Enroll  2.690465      Highly Skewed        Right
# 3     Top10perc  1.413217      Highly Skewed        Right
# 4     Top25perc  0.259340             Normal  Symmetrical
# 5   F.Undergrad  2.610458      Highly Skewed        Right
# 6   P.Undergrad  5.692353      Highly Skewed        Right
# 7      Outstate  0.509278  Moderately Skewed        Right
# 8    Room.Board  0.477356             Normal  Symmetrical
# 9         Books  3.485025      Highly Skewed        Right
# 10     Personal  1.742497      Highly Skewed        Right
# 11          PhD -0.793795  Moderately Skewed         Left
# 12     Terminal -0.816542  Moderately Skewed         Left
# 13    S.F.Ratio  0.667435  Moderately Skewed        Right
# 14  perc.alumni  0.606891  Moderately Skewed        Right
# 15       Expend  3.459322      Highly Skewed        Right
# 16    Grad.Rate -0.137621             Normal  Symmetrical
#
#    Recommended Transformation
# 0                     Box-Cox
# 1                     Box-Cox
# 2                     Box-Cox
# 3                     Box-Cox
# 4                        None
# 5                     Box-Cox
# 6                     Box-Cox
# 7                     Box-Cox
# 8                        None
# 9                     Box-Cox
# 10                    Box-Cox
# 11                    Box-Cox
# 12                    Box-Cox
# 13                    Box-Cox
# 14                Yeo-Johnson
# 15                    Box-Cox
# 16                       None

# %%
# Now import the function from myutils

# %%
df['Books'].values.reshape(-1, 1).flatten()
# Out:
# array([ 450,  750,  400,  450,  800,  500,  500,  450,  300,  660,  500,
#         400,  600,  400,  650,  450,  660,  550,  900,  500,  400,   96,
#         350,  700,  500,  450,  500,  600,  540,  540,  600,  400,  750,
#         400, 1000,  500,  750,  600,  600,  600,  400,  750,  300,  650,
#         355,  660,  350,  600,  630,  350,  550,  500,  600,  650,  400,
#         500,  500,  450,  400,  475, 1495,  600,  500, 2000,  410,  500,
#         500,  600,  560,  860,  720,  500,  800,  450,  500,  300,  425,
#         612,  612,  600,  400,  600,  600,  400,  500,  300,  550,  450,
#         480,  400,  500,  525,  400,  600,  526,  600,  500,  570,  500,
#         600, 2340,  650,  500,  300,  654,  600,  600,  600,  400,  700,
#         400,  600,  525,  500,  500,  500,  350,  700,  800,  600,  500,
#         400,  500,  500,  550,  666,  400,  500,  630,  600,  500,  450,
#         380,  800,  600,  450,  450,  400,  600,  500,  450,  470,  400,
#         500,  550,  450,  450,  570,  400,  600,  500,  550,  650,  400,
#         400,  680,  450,  500,  550,  600,  400,  500,  500,  550,  595,
#         600,  500,  400,  600,  450,  450,  560,  520,  500,  625,  600,
#         500,  600,  530,  450,  650,  120,  600,  450,  600,  500,  450,
#         450,  490,  570,  700,  600,  450,  475,  330,  600,  700,  350,
#         500,  500,  750,  800,  400,  600,  350,  600,  500,  400,  600,
#         525,  500,  600,  630,  600,  500,  500,  500,  400,  580,  700,
#         550,  670,  795,  720,  500,  500,  531,  600,  400,  600,  500,
#         300,  550,  500,  400,  550,  400,  400,  525,  450,  400,  500,
#         300,  450,  660,  600,  500,  700,  700,  500,  500,  700,  500,
#         500,  400,  400,  600, 1000,  500,  450,  465,  500,  500,  300,
#         600,  350,  650,  600,  500,  537,  400,  500,  750,  600,  600,
#         700,  570,  640,  634,  500,  400,  400,  400,  600,  500,  500,
#         500,  450,  600,  500,  500,  500,  750,  600,  400,  600,  400,
#         600,  450,  600,  750,  920,  500,  508,  600,  528,  525,  400,
#         400,  750,  400,  550,  600,  450,  500,  600,  350, 1000,  500,
#         800,  225,  550,  500,  500,  600,  618,  600,  545,  600,  700,
#         600,  500,  450,  500,  500,  550,  450,  525,  500,  450,  450,
#         500,  470,  550,  600,  700,  600,  650,  575,  350,  500,  500,
#         425,  600,  725,  600,  500,  400,  600,  400,  425,  450,  375,
#         540,  475,  500,  504,  900, 1100,  450,  550,  450,  550, 1000,
#         600,  480,  600,  200,  400,  400,  530,  550,  550,  700,  500,
#         600,  550,  250,  500,  850,  750,  500,  550,  500,  500,  550,
#         250,  630,  400,  600,  600,  700,  600,  650,  550,  700,  600,
#         450,  500,  450,  500,  600,  600,  600,  450,  600,  400,  400,
#         600,  620,  470,  250,  450,  300,  759,  500,  400,  400,  575,
#         558,  600,  600,  550,  550,  515,  500,  800,  420,  500,  616,
#         660,  600,  630,  450,  550,  512,  500,  500,  400,  600,  600,
#         600,  500,  650,  800,  400,  436,  598,  554,  675,  450,  570,
#         610,  450, 1000,  500,  600,  400,  370,  500,  450, 1230,  550,
#         700,  350,  600,  450,  500,  600,  500,  955,  550,  800,  690,
#         690,  690,  400,  500,  450,  350,  450,  400,  500,  600,  500,
#         350,  650,  800,  500,  400,  500,  500,  550,  500,  500,  600,
#         400,  500,  600,  569,  612,  630,  600, 1200,  500,  600,  600,
#         500,  650,  350,  450,  500,  575,  475,  500,  550,  500,  500,
#         500,  500,  200,  450,  630,  221,  576,  400,  500,  600,  430,
#         550,  600,  600,  660,  385,  500,  275,  400,  650,  300,  630,
#         675,  700,  425,  600,  500,  450,  600,  450,  711,  480,  700,
#         700,  708,  600,  500,  500,  550,  630,  620,  600,  550,  600,
#         500, 1125,  400,  500,  635,  400, 1000,  450,  400,  600,  600,
#         650,  490,  600,  600,  400,  700,  600,  500,  700,  468,  500,
#         500,  550,  500,  350,  450,  600,  500,  450,  518,  750,  500,
#         636,  790,  700,  400,  500,  556,  700,  500,  500,  530,  400,
#         600,  400,  700,  630,  525,  500,  687,  500,  630,  525,  700,
#         630,  530,  450,  600,  400,  494,  550,  500,  500,  630,  476,
#         753,  600,  714,  600,  600,  700,  500,  550,  300,  500,  900,
#         650,  600,  550,  600,  600,  500,  450,  600,  450,  540,  595,
#         600,  765,  570,  500,  400,  600,  630,  500,  700,  500,  630,
#         750,  600,  650,  500,  495,  500,  600,  540,  500,  500,  500,
#         500,  750,  500,  650,  452, 1300,  646,  450, 1200,  858,  500,
#         500,  708,  541,  376,  550,  300,  475,  535,  570,  600,  500,
#         500,  450,  600,  500,  630,  600,  400,  500,  500,  740,  500,
#         500,  500,  500,  500,  585,  500,  500,  400,  400,  300,  680,
#         500,  800,  768,  540,  500,  650,  500,  500,  600,  850,  500,
#        1400,  400,  600,  450,  110,  500,  500,  498,  500,  639,  500,
#         600,  430,  600,  490,  530,  700,  600,  750,  500,  678,  500,
#         550,  400,  500,  550,  500,  450,  550,  300,  580,  500,  400,
#         605,  530,  500,  600,  617,  630,  500])

# %%
def plot_transformations(df, skew_table):
    """
    Applies the recommended transformation to each column, then plots the before and after 
    distributions side by side with the skewness degree on each subplot.
    """
# Your code here

    transformed_df = df.copy()

    for _, row in skew_table.iterrows():

        column = row['Feature']
        transformation = row['Recommended Transformation']

        original_data = df[column].dropna().astype(float)

        # Apply transformation
        if transformation == 'Log Plus One':

            transformed_data = np.log1p(original_data)

        elif transformation == 'Box-Cox':

            transformer = PowerTransformer(
                method='box-cox',
            )

            transformed_data = transformer.fit_transform(
                original_data.values.reshape(-1, 1)
            ).flatten()

        elif transformation == 'Yeo-Johnson':

            transformer = PowerTransformer(
                method='yeo-johnson',
                standardize=False
            )

            transformed_data = transformer.fit_transform(
                original_data.values.reshape(-1, 1)
            ).flatten()

        else:

            transformed_data = original_data.values

        # Save transformed column as float
        transformed_df[column] = pd.Series(
            transformed_data,
            index=original_data.index,
            dtype=float
        )

        # Skewness
        original_skew = original_data.skew()
        transformed_skew = pd.Series(transformed_data).skew()

        # Plot
        fig, axes = plt.subplots(1, 2, figsize=(12,4))

        sns.histplot(original_data, kde=True, ax=axes[0])
        axes[0].set_title(
            f'{column} Before\nSkew={original_skew:.2f}'
        )

        sns.histplot(transformed_data, kde=True, ax=axes[1])
        axes[1].set_title(
            f'{column} After ({transformation})\nSkew={transformed_skew:.2f}'
        )

        plt.tight_layout()
        plt.show()

    return transformed_df

# %%
transformed_df = plot_transformations(df, skew_table)

# %% [markdown]
# #### 6. Run the functions on your cleaned DataFrame
#
# - Call `skew_calc()` and check the table, does the classification match what you expected for these features?
# - Call `plot_transformations()`, is the change significant?

# %%
# Your code here
skew_table = skew_calc(df)

skew_table
# Out:
#         Feature  Skewness             Degree    Direction  \
# 0          Apps  3.723750      Highly Skewed        Right
# 1        Accept  3.417727      Highly Skewed        Right
# 2        Enroll  2.690465      Highly Skewed        Right
# 3     Top10perc  1.413217      Highly Skewed        Right
# 4     Top25perc  0.259340             Normal  Symmetrical
# 5   F.Undergrad  2.610458      Highly Skewed        Right
# 6   P.Undergrad  5.692353      Highly Skewed        Right
# 7      Outstate  0.509278  Moderately Skewed        Right
# 8    Room.Board  0.477356             Normal  Symmetrical
# 9         Books  3.485025      Highly Skewed        Right
# 10     Personal  1.742497      Highly Skewed        Right
# 11          PhD -0.793795  Moderately Skewed         Left
# 12     Terminal -0.816542  Moderately Skewed         Left
# 13    S.F.Ratio  0.667435  Moderately Skewed        Right
# 14  perc.alumni  0.606891  Moderately Skewed        Right
# 15       Expend  3.459322      Highly Skewed        Right
# 16    Grad.Rate -0.137621             Normal  Symmetrical
#
#    Recommended Transformation
# 0                     Box-Cox
# 1                     Box-Cox
# 2                     Box-Cox
# 3                     Box-Cox
# 4                        None
# 5                     Box-Cox
# 6                     Box-Cox
# 7                     Box-Cox
# 8                        None
# 9                     Box-Cox
# 10                    Box-Cox
# 11                    Box-Cox
# 12                    Box-Cox
# 13                    Box-Cox
# 14                Yeo-Johnson
# 15                    Box-Cox
# 16                       None

# %%
# Your code here
# Out:
#         Feature  Skewness                   Degree Direction  \
# 0          Apps  3.723750            Highly Skewed  Positive
# 1        Accept  3.417727            Highly Skewed  Positive
# 2        Enroll  2.690465            Highly Skewed  Positive
# 3     Top10perc  1.413217            Highly Skewed  Positive
# 4     Top25perc  0.259340  Approximately Symmetric  Positive
# 5   F.Undergrad  2.610458            Highly Skewed  Positive
# 6   P.Undergrad  5.692353            Highly Skewed  Positive
# 7      Outstate  0.509278        Moderately Skewed  Positive
# 8    Room.Board  0.477356  Approximately Symmetric  Positive
# 9         Books  3.485025            Highly Skewed  Positive
# 10     Personal  1.742497            Highly Skewed  Positive
# 11          PhD -0.786217        Moderately Skewed  Negative
# 12     Terminal -0.816542        Moderately Skewed  Negative
# 13    S.F.Ratio  0.667435        Moderately Skewed  Positive
# 14  perc.alumni  0.606891        Moderately Skewed  Positive
# 15       Expend  3.459322            Highly Skewed  Positive
# 16    Grad.Rate -0.137621  Approximately Symmetric  Negative
#
#    Recommended Transformation
# 0      Box-Cox or Yeo-Johnson
# 1      Box-Cox or Yeo-Johnson
# 2      Box-Cox or Yeo-Johnson
# 3      Box-Cox or Yeo-Johnson
# 4                 None needed
# 5      Box-Cox or Yeo-Johnson
# 6      Box-Cox or Yeo-Johnson
# 7      Box-Cox or Yeo-Johnson
# 8                 None needed
# 9      Box-Cox or Yeo-Johnson
# 10     Box-Cox or Yeo-Johnson
# 11     Box-Cox or Yeo-Johnson
# 12     Box-Cox or Yeo-Johnson
# 13     Box-Cox or Yeo-Johnson
# 14    log(x+1) or Yeo-Johnson
# 15     Box-Cox or Yeo-Johnson
# 16                None needed

# %%
# Your code here
transformed_df = plot_transformations(df, skew_table)

# %%
# No code here

# %% [markdown]
# ## Part C: Apply the transformations

# %% [markdown]
# #### 7. Create transformed versions of the skewed columns
#
# - Create a new column for each of the skewed columns based on the recommendations.

# %%
trans_cols = []

# Your code here 
for _, row in skew_table.iterrows():

    col = row['Feature']
    transform = row['Recommended Transformation']

    if transform == 'None':
        continue

    if transform == 'Log Plus One':
        df[col + '_trans'] = np.log1p(df[col])

    elif transform == 'Box-Cox':
        transformer = PowerTransformer(method='box-cox', standardize=False)
        df[col + '_trans'] = transformer.fit_transform(df[[col]]).flatten()

    elif transform == 'Yeo-Johnson':
        transformer = PowerTransformer(method='yeo-johnson', standardize=False)
        df[col + '_trans'] = transformer.fit_transform(
            df[[col]]).flatten()

    trans_cols.append(df[col + '_trans'])

pd.DataFrame(trans_cols).T
# Out:
#      Apps_trans  Accept_trans  Enroll_trans  Top10perc_trans  \
# 0      5.730375      5.620215      4.143049         4.810281
# 1      5.889258      5.888543      4.014993         4.037028
# 2      5.642123      5.548986      3.847907         4.711661
# 3      4.883064      4.814571      3.453920         7.235080
# 4      4.372223      4.215432      2.993412         4.037028
# ..          ...           ...           ...              ...
# 772    5.892126      5.745713      4.037465         1.664109
# 773    5.826353      5.850617      4.129630         4.905760
# 774    5.865469      5.885764      4.129630         5.727507
# 775    6.746592      6.031314      4.352721         8.625788
# 776    6.066028      5.866869      4.127514         5.260422
#
#      F.Undergrad_trans  P.Undergrad_trans  Outstate_trans  Books_trans  \
# 0             3.769302           8.713915       59.142209     9.288880
# 1             3.756515          10.316290       70.781897    10.448462
# 2             3.568664           5.815935       68.600055     9.032160
# 3             3.401005           5.119856       72.157160     9.288880
# 4             3.202743           9.631371       59.483775    10.600468
# ..                 ...                ...             ...          ...
# 772           3.781154          11.357650       57.247446     9.521847
# 773           3.767105          10.109510       69.184276     9.932528
# 774           3.763618           6.650988       57.558658     9.996318
# 775           3.866398           5.540753       83.965419    10.044074
# 776           3.775409          11.017126       51.195568     9.521847
#
#      Personal_trans    PhD_trans  Terminal_trans  S.F.Ratio_trans  \
# 0         10.374877  2504.239962    34148.774234         7.965493
# 1          9.706972   427.169553     2801.807925         5.909038
# 2          9.276476  1433.028797    22055.928365         6.170678
# 3          8.798545  4333.028101    60412.083923         4.059557
# 4          9.706972  2953.457225    27695.561321         5.795125
# ..              ...          ...             ...              ...
# 772        9.326479  1838.046435    17187.345783         8.878126
# 773        9.395617  2724.206159    30817.866345         6.317705
# 774        8.611589  2293.556337    30817.866345         6.713414
# 775       10.305285  4719.232116    58795.900380         3.154042
# 776        9.395617  2876.008413    30817.866345         7.965493
#
#      perc.alumni_trans  Expend_trans
# 0             4.953607      1.828730
# 1             5.900711      1.831689
# 2             8.505877      1.830396
# 3             9.568133      1.835020
# 4             1.435605      1.831929
# ..                 ...           ...
# 772           5.444039      1.824508
# 773           8.664947      1.830760
# 774           6.734950      1.830040
# 775          11.169602      1.837974
# 776           8.179319      1.824602
#
# [777 rows x 14 columns]

# %% [markdown]
# ## Part D: Feature Engineering and Encoding

# %% [markdown]
# #### 8. Engineer a new feature called `Accept_Rate`
#
# - An acceptance rate is more meaningful than the counts of applicants and accepted students on their own.

# %%
# Your code here 
df['Accept_Rate'] = df['Accept'] / df['Apps']

df['Accept_Rate'] = (df['Accept'] / df['Apps']) * 100

df[['Accept_Rate']]
# Out:
#      Accept_Rate
# 0      74.216867
# 1      88.014639
# 2      76.820728
# 3      83.693046
# 4      75.647668
# ..           ...
# 772    68.957670
# 773    92.138846
# 774    91.320935
# 775    22.914526
# 776    62.060890
#
# [777 rows x 1 columns]

# %% [markdown]
# #### 9. Bin `Outstate` into a new column called `Outstate_Tier`
#
# - Use `pd.cut()` to split out-of-state tuition into bins.

# %%
# Your code here 
df['Outstate_Tier'] = pd.cut(
    df['Outstate'],
    bins=3,
    labels=['Low', 'Medium', 'High'])

df[['Outstate', 'Outstate_Tier']].head()
# Out:
#    Outstate Outstate_Tier
# 0      7440           Low
# 1     12280        Medium
# 2     11250        Medium
# 3     12960        Medium
# 4      7560           Low

# %% [markdown]
# #### 10. Ordinally encode `Outstate_Tier`
#
# - Create a new column that maps the tiers ordinally.

# %%
# Your code here 
df['Outstate_Tier_Encoded'] = df['Outstate_Tier'].map({
    'Low': 0,
    'Medium': 1,
    'High': 2
})

df[['Outstate_Tier', 'Outstate_Tier_Encoded']].head()
# Out:
#   Outstate_Tier Outstate_Tier_Encoded
# 0           Low                     0
# 1        Medium                     1
# 2        Medium                     1
# 3        Medium                     1
# 4           Low                     0

# %% [markdown]
# #### 11. Binary encode `Private`
#
# - Create a new coumn that maps `Yes` to 1 and `No` to 0.

# %%
# Your code here 

df['Private_Encoded'] = df['Private'].map({
    'Yes': 1,
    'No': 0
})

df[['Private', 'Private_Encoded']].head()
# Out:
#   Private  Private_Encoded
# 0     Yes                1
# 1     Yes                1
# 2     Yes                1
# 3     Yes                1
# 4     Yes                1

# %%
df.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  ...  Outstate_Tier_Encoded  \
# 0         52         2885          537      7440  ...                      0
# 1         29         2683         1227     12280  ...                      1
# 2         50         1036           99     11250  ...                      1
# 3         89          510           63     12960  ...                      1
# 4         44          249          869      7560  ...                      0
#
#    Private_Encoded  Outstate_Tier_Encoded_scaled  Private_Encoded_scaled  \
# 0                1                     -1.098797                0.612553
# 1                1                      0.358140                0.612553
# 2                1                      0.358140                0.612553
# 3                1                      0.358140                0.612553
# 4                1                     -1.098797                0.612553
#
#    Outstate_Tier_Encoded_scaled  Private_Encoded_scaled  Accept_Rate_scaled  \
# 0                     -1.098797                0.612553           -0.032372
# 1                      0.358140                0.612553            0.906193
# 2                      0.358140                0.612553            0.144750
# 3                      0.358140                0.612553            0.612225
# 4                     -1.098797                0.612553            0.064955
#
#    Outstate_Tier_Encoded_scaled  Private_Encoded_scaled  Accept_Rate_scaled
# 0                     -1.098797                0.612553           -0.032372
# 1                      0.358140                0.612553            0.906193
# 2                      0.358140                0.612553            0.144750
# 3                      0.358140                0.612553            0.612225
# 4                     -1.098797                0.612553            0.064955
#
# [5 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   College                       777 non-null    str
#  1   Private                       777 non-null    str
#  2   Apps                          777 non-null    int64
#  3   Accept                        777 non-null    int64
#  4   Enroll                        777 non-null    int64
#  5   Top10perc                     777 non-null    int64
#  6   Top25perc                     777 non-null    int64
#  7   F.Undergrad                   777 non-null    int64
#  8   P.Undergrad                   777 non-null    int64
#  9   Outstate                      777 non-null    int64
#  10  Room.Board                    777 non-null    int64
#  11  Books                         777 non-null    int64
#  12  Personal                      777 non-null    int64
#  13  PhD                           777 non-null    float64
#  14  Terminal                      777 non-null    int64
#  15  S.F.Ratio                     777 non-null    float64
#  16  perc.alumni                   777 non-null    int64
#  17  Expend                        777 non-null    int64
#  18  Grad.Rate                     777 non-null    int64
#  19  Apps_trans                    777 non-null    float64
#  20  Accept_trans                  777 non-null    float64
#  21  Enroll_trans                  777 non-null    float64
#  22  Top10perc_trans               777 non-null    float64
#  23  F.Undergrad_trans             777 non-null    float64
#  24  P.Undergrad_trans             777 non-null    float64
#  25  Outstate_trans                777 non-null    float64
#  26  Books_trans                   777 non-null    float64
#  27  Personal_trans                777 non-null    float64
#  28  PhD_trans                     777 non-null    float64
#  29  Terminal_trans                777 non-null    float64
#  30  S.F.Ratio_trans               777 non-null    float64
#  31  perc.alumni_trans             777 non-null    float64
#  32  Expend_trans                  777 non-null    float64
#  33  Accept_Rate                   777 non-null    float64
#  34  Outstate_Tier                 777 non-null    category
#  35  Outstate_Tier_Encoded         777 non-null    category
#  36  Private_Encoded               777 non-null    int64
#  37  Outstate_Tier_Encoded_scaled  777 non-null    float64
#  38  Private_Encoded_scaled        777 non-null    float64
#  39  Outstate_Tier_Encoded_scaled  777 non-null    float64
#  40  Private_Encoded_scaled        777 non-null    float64
#  41  Accept_Rate_scaled            777 non-null    float64
#  42  Outstate_Tier_Encoded_scaled  777 non-null    float64
#  43  Private_Encoded_scaled        777 non-null    float64
#  44  Accept_Rate_scaled            777 non-null    float64
#  45  Outstate_Tier_Encoded_scaled  777 non-null    float64
#  46  Accept_Rate_scaled            777 non-null    float64
# dtypes: category(2), float64(27), int64(16), str(2)
# memory usage: 293.9 KB

# %% [markdown]
# ## Part E: Scale and Explore

# %% [markdown]
# #### 12. Standardize the transformed and encoded features
#
# - Use `StandardScaler` on all transformed columns from question 7, plus the encoded features and store the results in new columns.

# %%
cols_to_scale = []

# Your code here
cols_to_scale = trans_cols + ['Outstate_Tier', 'Outstate_Tier_Encoded', 'Accept_Rate']
scaler = StandardScaler()

scaled_data = scaler.fit_transform(df[cols_to_scale])

scaled_df = pd.DataFrame(
    scaled_data,
    columns=[col + '_scaled' for col in cols_to_scale],
    index=df.index
)

df = pd.concat([df, scaled_df], axis=1)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 7
#       3 # Your code here
#       4 cols_to_scale = trans_cols + ['Outstate_Tier', 'Outstate_Tier_Encoded', 'Accept_Rate']
#       5 scaler = StandardScaler()
#       6
# ----> 7 scaled_data = scaler.fit_transform(df[cols_to_scale])
#       8
#       9 scaled_df = pd.DataFrame(
#      10     scaled_data,
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sklearn\base.py:969, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     954         warnings.warn(
#     955             (
#     956                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    964             UserWarning,
#     965         )
#     967 if y is None:
#     968     # fit method of arity 1 (unsupervised transformation)
# --> 969     return self.fit(X, **fit_params).transform(X)
#     970 else:
#     971     # fit method of arity 2 (supervised transformation)
#     972     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sklearn\preprocessing\_data.py:928, in StandardScaler.fit(self, X, y, sample_weight)
#     926 # Reset internal state before fitting
#     927 self._reset()
# --> 928 return self.partial_fit(X, y, sample_weight)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sklearn\preprocessing\_data.py:965, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     963 xp, _, X_device = get_namespace_and_device(X)
#     964 first_call = not hasattr(self, "n_samples_seen_")
# --> 965 X = validate_data(
#     966     self,
#     967     X,
#     968     accept_sparse=("csr", "csc"),
#     969     dtype=supported_float_dtypes(xp, X_device),
#     970     ensure_all_finite="allow-nan",
#     971     reset=first_call,
#     972 )
#     973 n_features = X.shape[1]
#     975 callback_ctx = self._init_callback_context()
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sklearn\utils\validation.py:3038, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3036         out = X, y
#    3037 elif not no_val_X and no_val_y:
# -> 3038     out = check_array(X, input_name="X", **check_params)
#    3039 elif no_val_X and not no_val_y:
#    3040     out = _check_y(y, **check_params)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sklearn\utils\validation.py:1035, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1033         array = xp.astype(array, dtype, copy=False)
#    1034     else:
# -> 1035         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1036 except ComplexWarning as complex_warning:
#    1037     raise ValueError(
#    1038         "Complex data not supported\n{}\n".format(array)
#    1039     ) from complex_warning
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sklearn\utils\_array_api.py:976, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     974     array = numpy.array(array, order=order, dtype=dtype)
#     975 else:
# --> 976     array = numpy.asarray(array, order=order, dtype=dtype)
#     978 # At this point array is a NumPy ndarray. We convert it to an array
#     979 # container that is consistent with the input's namespace.
#     980 return xp.asarray(array)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\pandas\core\generic.py:2027, in NDFrame.__array__(self, dtype, copy)
#    2023             )
#    2024         values = self._values
#    2025         if copy is None:
#    2026             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2027             arr = np.asarray(values, dtype=dtype)
#    2028         else:
#    2029             arr = np.array(values, dtype=dtype, copy=copy)
#    2030
#
# ValueError: could not convert string to float: 'Low'

# %% [markdown]
# #### 13. Plot a correlation heatmap of your numeric features
#
# - Include the scaled columns from question 12 along with other columns
# - Which features look most related to `Grad.Rate`?
# - Check and drop highly correlated features

# %%
# Your code here 
plt.figure(figsize=(16,12))

sns.heatmap(
    df.select_dtypes(include=np.number).corr(),
    cmap='coolwarm',
    center=0
)

plt.show()

# %% [markdown]
# ## Part F: Does the Transformation Help?

# %% [markdown]
# #### 14. Split your data into train and test sets
#
# - Train the model twice: once using the untransformed columns, and once using the transformed versions, so we can see whether the transformation actually improved the fit
# - In both cases, the target will be `Grad.Rate`

# %%
# Your code here

# %% [markdown]
# #### 15. Fit a linear regression using the raw predictors

# %%
untrans_predictors = []

# Your code here

# %% [markdown]
# #### 16. Fit the same model using the log-transformed predictors

# %%
trans_predictors = []

# Your code here

# %% [markdown]
# #### 17. Compare the two R-squared scores
#
# - Is there an improvement in the results?

# %%
# Your code here

# %% [markdown]
# #### 18. Export your cleaned and transformed `DataFrame` to a new CSV file called `college_transformed.csv`

# %%
# Your code here
