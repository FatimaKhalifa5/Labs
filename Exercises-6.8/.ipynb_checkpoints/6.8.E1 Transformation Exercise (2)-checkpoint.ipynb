# %% [markdown]
# <img src="../assets/ga-logo.png" style="float: left; margin: 20px; height: 55px">
#
# # Exercise - `pandas` Data Transformation
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# ## Part A: Load and Clean

# %% [markdown]
# #### 1. Load `College.csv`
#
# - The first column doesn't have an accurate name, rename it.

# %%
# Your code here
df= pd.read_csv('./data/College.csv')
df.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#   PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0  70        78       18.1           12    7041         60
# 1  29        30       12.2           16   10527         56
# 2  53        66       12.9           30    8735         54
# 3  92        97        7.7           37   19016         59
# 4  76        72       11.9            2   10922         15

# %%
df.rename(columns={df.columns[0]: 'College'}, inplace=True)

df.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#   PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0  70        78       18.1           12    7041         60
# 1  29        30       12.2           16   10527         56
# 2  53        66       12.9           30    8735         54
# 3  92        97        7.7           37   19016         59
# 4  76        72       11.9            2   10922         15

# %% [markdown]
# #### 2. Check the shape, the data types of each column, and the number of missing values per column

# %%
# Your code here
df.shape
# Out:
# (777, 19)

# %%
df.dtypes
# Out:
# College            str
# Private            str
# Apps             int64
# Accept           int64
# Enroll           int64
# Top10perc        int64
# Top25perc        int64
# F.Undergrad      int64
# P.Undergrad      int64
# Outstate         int64
# Room.Board       int64
# Books            int64
# Personal         int64
# PhD                str
# Terminal         int64
# S.F.Ratio      float64
# perc.alumni      int64
# Expend           int64
# Grad.Rate        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# College        0
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# dtype: int64

# %% [markdown]
# #### 3. Fix the `PhD` column
#
# - `PhD` is the percentage of faculty with a PhD, but it has inaccurate entries.
# - Fix the column and fill these entries with the plausible values.

# %%
# Your code here
df['PhD'].value_counts()
# Out:
# PhD
# ?      29
# 77     26
# 73     24
# 90     22
# 71     21
#        ..
# 32      1
# 14      1
# 103     1
# 26      1
# 16      1
# Name: count, Length: 78, dtype: int64

# %%
# Replace invalid values with NaN
df['PhD'] = df['PhD'].replace('?', np.nan)

# Convert to numeric
df['PhD'] = pd.to_numeric(df['PhD'])

# Replace values greater than 100 with NaN
df.loc[df['PhD'] > 100, 'PhD'] = np.nan

# Fill missing values with the median
df['PhD'] = df['PhD'].fillna(df['PhD'].median())

# Check the result
df['PhD'].value_counts()
# Out:
# PhD
# 75.0    51
# 77.0    26
# 73.0    24
# 90.0    22
# 71.0    21
#         ..
# 34.0     1
# 32.0     1
# 14.0     1
# 26.0     1
# 16.0     1
# Name: count, Length: 76, dtype: int64

# %%
df['PhD'].dtype
# Out:
# dtype('float64')

# %%
df['PhD']
# Out:
# 0      70.0
# 1      29.0
# 2      53.0
# 3      92.0
# 4      76.0
#        ...
# 772    60.0
# 773    73.0
# 774    67.0
# 775    96.0
# 776    75.0
# Name: PhD, Length: 777, dtype: float64

# %% [markdown]
# #### 4. Fix the `Grad.Rate` column
#
# - `Grad.Rate` is the graduation rate, but it has data entry errors.

# %%
# Your code here
df[df['Grad.Rate'] > 100]
# Out:
#               College Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# 95  Cazenovia College     Yes  3847    3433     527          9         35
#
#     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal   PhD  \
# 95         1010           12      9384        4840    600       500  22.0
#
#     Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 95        47       14.3           20    7697        118

# %%
# Replace graduation rates above 100 with 100
df.loc[df['Grad.Rate'] > 100, 'Grad.Rate'] = 100
df[df['Grad.Rate'] > 100]
# Out:
# Empty DataFrame
# Columns: [College, Private, Apps, Accept, Enroll, Top10perc, Top25perc, F.Undergrad, P.Undergrad, Outstate, Room.Board, Books, Personal, PhD, Terminal, S.F.Ratio, perc.alumni, Expend, Grad.Rate]
# Index: []

# %% [markdown]
# ## Part B: Diagnose, Transform, and Visualize Skew

# %% [markdown]
# #### The tables bellow can be used as a reference to classify the the degree and distribution of the skewness as well as the right distribution transformation method.

# %% [markdown]
# ### Table1: Skewness Score Interpretation
#
# | Skewness Score Range | Distribution Shape |
# | :--- | :--- |
# | **Less than -1** | Highly Skewed (Left) |
# | **Between -1 and -0.5** | Moderately Skewed (Left) |
# | **Between -0.5 and 0.5** | `Normal (Symmetrical)` |
# | **Between 0.5 and 1** | Moderately Skewed (Right) |
# | **Greater than 1** | Highly Skewed (Right) |

# %% [markdown]
# ### Table2: Decision Matrix: Choosing the Right Distribution Transformation
#
# | Transformation | Best Data Shape / Scenario | Handles Zeros? | Handles Negatives? | Impact on Linear Models / Interpretability |
# | :--- | :--- | :--- | :--- | :--- |
# | **Log Plus One ($\log(x+1)$)** | Highly Right-Skewed with zero counts |  Yes | ❌ No | Safely maps zero values to zero while retaining standard log-compression benefits. |
# | **Box-Cox** | Right or Left Skewed (Strictly positive) | ❌ No | ❌ No | Automatically searches for the mathematically ideal power exponent ($\lambda$) to maximize normality. |
# | **Yeo-Johnson** | Right or Left Skewed (Versatile) |  Yes |  Yes | Modifies the Box-Cox algorithm to safely calculate ideal power scales across zeros and negatives. |

# %% [markdown]
# #### 5. Write `skew_calc()` with `%%writefile`, then `plot_transformations()` here
#
# - `skew_calc(df)`: for every numeric column, calculate its skewness, classify the degree and direction, and recommend a transformation. Use `%%writefile` to save this into `myutils.py`, then import it.
# - `plot_transformations(df, skew_table)`: take a DataFrame together with the output of `skew_calc()`, apply the **best** recommended transformation to each column, and plot the before and after distributions side by side with the skewness labeled on each subplot.

# %%
# %%writefile myutils.py
import numpy as np
import pandas as pd

def skew_calc(df):
    """
    Diagnoses skewness for every numeric column in a DataFrame and recommends a transformation based on the column's skewness and
    minimum value. Binary, encoded, and ID columns are excluded, since skewness isn't a meaningful for them.
    It returns a DataFrame with the following columns:
    Feature, Skewness, Degree, Direction, Recommended Transformation
    """
    # Your code here 

    results = []

    # Select numeric columns only
    numeric_columns = df.select_dtypes(include=np.number).columns

    # Skip binary indicators (0/1) or columns ending with '_id'

    for column in numeric_columns:
        
        if 'id' in str(column).lower() or df[column].nunique() <= 2:
            continue

        # Skip binary columns
        if df[column].nunique() <= 2:
            continue

        skewness = df[column].skew()
        minimum = df[column].min()

        

        # Classify degree and direction
        if skewness < -1:
            degree = 'Highly Skewed'
            direction = 'Left'

        elif -1 <= skewness < -0.5:
            degree = 'Moderately Skewed'
            direction = 'Left'

        elif -0.5 <= skewness <= 0.5:
            degree = 'Normal'
            direction = 'Symmetrical'

        elif 0.5 < skewness <= 1:
            degree = 'Moderately Skewed'
            direction = 'Right'

        else:
            degree = 'Highly Skewed'
            direction = 'Right'

        # Recommend transformation
        if -0.5 <= skewness <= 0.5:
            transformation = 'None'

        elif minimum < 0:
            transformation = 'Yeo-Johnson'

        elif minimum == 0 and skewness > 1:
            transformation = 'Log Plus One'

        elif minimum > 0:
            transformation = 'Box-Cox'

        else:
            transformation = 'Yeo-Johnson'

        results.append({
            'Feature': column,
            'Skewness': skewness,
            'Degree': degree,
            'Direction': direction,
            'Recommended Transformation': transformation
        })

    return pd.DataFrame(results)
# Out:
# Overwriting myutils.py

# %%
# Now import the function from myutils
from myutils import skew_calc

# %%
skew_table = skew_calc(df)

skew_table
# Out:
#         Feature  Skewness             Degree    Direction  \
# 0          Apps  3.723750      Highly Skewed        Right
# 1        Accept  3.417727      Highly Skewed        Right
# 2        Enroll  2.690465      Highly Skewed        Right
# 3     Top10perc  1.413217      Highly Skewed        Right
# 4     Top25perc  0.259340             Normal  Symmetrical
# 5   F.Undergrad  2.610458      Highly Skewed        Right
# 6   P.Undergrad  5.692353      Highly Skewed        Right
# 7      Outstate  0.509278  Moderately Skewed        Right
# 8    Room.Board  0.477356             Normal  Symmetrical
# 9         Books  3.485025      Highly Skewed        Right
# 10     Personal  1.742497      Highly Skewed        Right
# 11          PhD -0.793795  Moderately Skewed         Left
# 12     Terminal -0.816542  Moderately Skewed         Left
# 13    S.F.Ratio  0.667435  Moderately Skewed        Right
# 14  perc.alumni  0.606891  Moderately Skewed        Right
# 15       Expend  3.459322      Highly Skewed        Right
# 16    Grad.Rate -0.137621             Normal  Symmetrical
#
#    Recommended Transformation
# 0                     Box-Cox
# 1                     Box-Cox
# 2                     Box-Cox
# 3                     Box-Cox
# 4                        None
# 5                     Box-Cox
# 6                     Box-Cox
# 7                     Box-Cox
# 8                        None
# 9                     Box-Cox
# 10                    Box-Cox
# 11                    Box-Cox
# 12                    Box-Cox
# 13                    Box-Cox
# 14                Yeo-Johnson
# 15                    Box-Cox
# 16                       None

# %%
# Now import the function from myutils

# %%
def plot_transformations(df, skew_table):
    """
    Applies the recommended transformation to each column, then plots the before and after 
    distributions side by side with the skewness degree on each subplot.
    """
    transformed_df = df.copy()

    for _, row in skew_table.iterrows():

        column = row['Feature']
        transformation = row['Recommended Transformation']

        if transformation == 'Log Plus One':
            transformed_df[column] = np.log1p(df[column])

        elif transformation == 'Box-Cox':
            transformer = PowerTransformer(method='box-cox')
            transformed_df[column] = transformer.fit_transform(df[[column]])

        elif transformation == 'Yeo-Johnson':
            transformer = PowerTransformer(method='yeo-johnson', standardize=False)
            transformed_df[column] = transformer.fit_transform(df[[column]])


        original_skew = df[column].skew()
        transformed_skew = transformed_df[column].skew()

        fig, axes = plt.subplots(1, 2, figsize=(12,4))

        sns.histplot(df[column], kde=True, ax=axes[0])
        axes[0].set_title(f'{column} Before\nSkew={original_skew:.2f}')

        sns.histplot(transformed_df[column], kde=True, ax=axes[1])
        axes[1].set_title(f'{column} After ({transformation})\nSkew={transformed_skew:.2f}')

        plt.tight_layout()
        plt.show()

    return transformed_df

# %%
transformed_df = plot_transformations(df, skew_table)

# %% [markdown]
# #### 6. Run the functions on your cleaned DataFrame
#
# - Call `skew_calc()` and check the table, does the classification match what you expected for these features?
# - Call `plot_transformations()`, is the change significant?

# %%
# Your code here
skew_table = skew_calc(df)

skew_table
# Out:
#         Feature  Skewness             Degree    Direction  \
# 0          Apps  3.723750      Highly Skewed        Right
# 1        Accept  3.417727      Highly Skewed        Right
# 2        Enroll  2.690465      Highly Skewed        Right
# 3     Top10perc  1.413217      Highly Skewed        Right
# 4     Top25perc  0.259340             Normal  Symmetrical
# 5   F.Undergrad  2.610458      Highly Skewed        Right
# 6   P.Undergrad  5.692353      Highly Skewed        Right
# 7      Outstate  0.509278  Moderately Skewed        Right
# 8    Room.Board  0.477356             Normal  Symmetrical
# 9         Books  3.485025      Highly Skewed        Right
# 10     Personal  1.742497      Highly Skewed        Right
# 11          PhD -0.793795  Moderately Skewed         Left
# 12     Terminal -0.816542  Moderately Skewed         Left
# 13    S.F.Ratio  0.667435  Moderately Skewed        Right
# 14  perc.alumni  0.606891  Moderately Skewed        Right
# 15       Expend  3.459322      Highly Skewed        Right
# 16    Grad.Rate -0.137621             Normal  Symmetrical
#
#    Recommended Transformation
# 0                     Box-Cox
# 1                     Box-Cox
# 2                     Box-Cox
# 3                     Box-Cox
# 4                        None
# 5                     Box-Cox
# 6                     Box-Cox
# 7                     Box-Cox
# 8                        None
# 9                     Box-Cox
# 10                    Box-Cox
# 11                    Box-Cox
# 12                    Box-Cox
# 13                    Box-Cox
# 14                Yeo-Johnson
# 15                    Box-Cox
# 16                       None

# %%
# Your code here

# %%
# Your code here
transformed_df = plot_transformations(df, skew_table)

# %%
# No code here

# %% [markdown]
# ## Part C: Apply the transformations

# %% [markdown]
# #### 7. Create transformed versions of the skewed columns
#
# - Create a new column for each of the skewed columns based on the recommendations.

# %%
# Your code here 
for _, row in skew_table.iterrows():

    col = row['Feature']
    transform = row['Recommended Transformation']

    if transform == 'None':
        continue

    if transform == 'Log Plus One':
        df[col + '_trans'] = np.log1p(df[col])

    elif transform == 'Box-Cox':
        transformer = PowerTransformer(method='box-cox', standardize=False)
        df[col + '_trans'] = transformer.fit_transform(df[[col]]).flatten()

    elif transform == 'Yeo-Johnson':
        transformer = PowerTransformer(method='yeo-johnson', standardize=False)
        df[col + '_trans'] = transformer.fit_transform(df[[col]]).flatten()

df.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  ...  F.Undergrad_trans  \
# 0         52         2885          537      7440  ...           3.769302
# 1         29         2683         1227     12280  ...           3.756515
# 2         50         1036           99     11250  ...           3.568664
# 3         89          510           63     12960  ...           3.401005
# 4         44          249          869      7560  ...           3.202743
#
#    P.Undergrad_trans  Outstate_trans  Books_trans  Personal_trans  \
# 0           8.713915       59.142209     9.288880       10.374877
# 1          10.316290       70.781897    10.448462        9.706972
# 2           5.815935       68.600055     9.032160        9.276476
# 3           5.119856       72.157160     9.288880        8.798545
# 4           9.631371       59.483775    10.600468        9.706972
#
#      PhD_trans  Terminal_trans  S.F.Ratio_trans  perc.alumni_trans  \
# 0  2504.239962    34148.774234         7.965493           4.953607
# 1   427.169553     2801.807925         5.909038           5.900711
# 2  1433.028797    22055.928365         6.170678           8.505877
# 3  4333.028101    60412.083923         4.059557           9.568133
# 4  2953.457225    27695.561321         5.795125           1.435605
#
#    Expend_trans
# 0      1.828730
# 1      1.831689
# 2      1.830396
# 3      1.835020
# 4      1.831929
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Part D: Feature Engineering and Encoding

# %% [markdown]
# #### 8. Engineer a new feature called `Accept_Rate`
#
# - An acceptance rate is more meaningful than the counts of applicants and accepted students on their own.

# %%
# Your code here 
df['Accept_Rate'] = df['Accept'] / df['Apps']

df['Accept_Rate'] = (df['Accept'] / df['Apps']) * 100

df[['Accept_Rate']]
# Out:
#      Accept_Rate
# 0      74.216867
# 1      88.014639
# 2      76.820728
# 3      83.693046
# 4      75.647668
# ..           ...
# 772    68.957670
# 773    92.138846
# 774    91.320935
# 775    22.914526
# 776    62.060890
#
# [777 rows x 1 columns]

# %% [markdown]
# #### 9. Bin `Outstate` into a new column called `Outstate_Tier`
#
# - Use `pd.cut()` to split out-of-state tuition into bins.

# %%
# Your code here 
df['Outstate_Tier'] = pd.cut(
    df['Outstate'],
    bins=3,
    labels=['Low', 'Medium', 'High'])

df[['Outstate', 'Outstate_Tier']].head()
# Out:
#    Outstate Outstate_Tier
# 0      7440           Low
# 1     12280        Medium
# 2     11250        Medium
# 3     12960        Medium
# 4      7560           Low

# %% [markdown]
# #### 10. Ordinally encode `Outstate_Tier`
#
# - Create a new column that maps the tiers ordinally.

# %%
# Your code here 
df['Outstate_Tier_Encoded'] = df['Outstate_Tier'].map({
    'Low': 0,
    'Medium': 1,
    'High': 2
})

df[['Outstate_Tier', 'Outstate_Tier_Encoded']].head()
# Out:
#   Outstate_Tier Outstate_Tier_Encoded
# 0           Low                     0
# 1        Medium                     1
# 2        Medium                     1
# 3        Medium                     1
# 4           Low                     0

# %% [markdown]
# #### 11. Binary encode `Private`
#
# - Create a new coumn that maps `Yes` to 1 and `No` to 0.

# %%
# Your code here 

df['Private_Encoded'] = df['Private'].map({
    'Yes': 1,
    'No': 0
})

df[['Private', 'Private_Encoded']].head()
# Out:
#   Private  Private_Encoded
# 0     Yes                1
# 1     Yes                1
# 2     Yes                1
# 3     Yes                1
# 4     Yes                1

# %%
df.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  ...  Personal_trans  \
# 0         52         2885          537      7440  ...       10.374877
# 1         29         2683         1227     12280  ...        9.706972
# 2         50         1036           99     11250  ...        9.276476
# 3         89          510           63     12960  ...        8.798545
# 4         44          249          869      7560  ...        9.706972
#
#      PhD_trans  Terminal_trans  S.F.Ratio_trans  perc.alumni_trans  \
# 0  2504.239962    34148.774234         7.965493           4.953607
# 1   427.169553     2801.807925         5.909038           5.900711
# 2  1433.028797    22055.928365         6.170678           8.505877
# 3  4333.028101    60412.083923         4.059557           9.568133
# 4  2953.457225    27695.561321         5.795125           1.435605
#
#    Expend_trans  Accept_Rate  Outstate_Tier  Outstate_Tier_Encoded  \
# 0      1.828730    74.216867            Low                      0
# 1      1.831689    88.014639         Medium                      1
# 2      1.830396    76.820728         Medium                      1
# 3      1.835020    83.693046         Medium                      1
# 4      1.831929    75.647668            Low                      0
#
#    Private_Encoded
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
#
# [5 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   College                777 non-null    str
#  1   Private                777 non-null    str
#  2   Apps                   777 non-null    int64
#  3   Accept                 777 non-null    int64
#  4   Enroll                 777 non-null    int64
#  5   Top10perc              777 non-null    int64
#  6   Top25perc              777 non-null    int64
#  7   F.Undergrad            777 non-null    int64
#  8   P.Undergrad            777 non-null    int64
#  9   Outstate               777 non-null    int64
#  10  Room.Board             777 non-null    int64
#  11  Books                  777 non-null    int64
#  12  Personal               777 non-null    int64
#  13  PhD                    777 non-null    float64
#  14  Terminal               777 non-null    int64
#  15  S.F.Ratio              777 non-null    float64
#  16  perc.alumni            777 non-null    int64
#  17  Expend                 777 non-null    int64
#  18  Grad.Rate              777 non-null    int64
#  19  Apps_trans             777 non-null    float64
#  20  Accept_trans           777 non-null    float64
#  21  Enroll_trans           777 non-null    float64
#  22  Top10perc_trans        777 non-null    float64
#  23  F.Undergrad_trans      777 non-null    float64
#  24  P.Undergrad_trans      777 non-null    float64
#  25  Outstate_trans         777 non-null    float64
#  26  Books_trans            777 non-null    float64
#  27  Personal_trans         777 non-null    float64
#  28  PhD_trans              777 non-null    float64
#  29  Terminal_trans         777 non-null    float64
#  30  S.F.Ratio_trans        777 non-null    float64
#  31  perc.alumni_trans      777 non-null    float64
#  32  Expend_trans           777 non-null    float64
#  33  Accept_Rate            777 non-null    float64
#  34  Outstate_Tier          777 non-null    category
#  35  Outstate_Tier_Encoded  777 non-null    category
#  36  Private_Encoded        777 non-null    int64
# dtypes: category(2), float64(17), int64(16), str(2)
# memory usage: 233.2 KB

# %% [markdown]
# ## Part E: Scale and Explore

# %% [markdown]
# #### 12. Standardize the transformed and encoded features
#
# - Use `StandardScaler` on all transformed columns from question 7, plus the encoded features and store the results in new columns.

# %%
# Your code here
cols_to_scale =['Accept_trans','Enroll_trans','Top10perc_trans','F.Undergrad_trans','P.Undergrad_trans','Outstate_trans',
'Books_trans','Personal_trans','PhD_trans','Terminal_trans','S.F.Ratio_trans','perc.alumni_trans','Expend_trans','Outstate_Tier_Encoded', 'Accept_Rate']
scaler = StandardScaler()

scaled_data = scaler.fit_transform(df[cols_to_scale])

scaled_df = pd.DataFrame(
    scaled_data,
    columns=[col + '_scaled' for col in cols_to_scale],
    index=df.index)

df = pd.concat([df, scaled_df], axis=1)

df.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  ...  Outstate_trans_scaled  \
# 0         52         2885          537      7440  ...              -0.693449
# 1         29         2683         1227     12280  ...               0.556268
# 2         50         1036           99     11250  ...               0.322011
# 3         89          510           63     12960  ...               0.703926
# 4         44          249          869      7560  ...              -0.656776
#
#    Books_trans_scaled  Personal_trans_scaled  PhD_trans_scaled  \
# 0           -0.614254               1.271398         -0.290438
# 1            1.302365               0.456551         -2.177364
# 2           -1.038575              -0.068655         -1.263585
# 3           -0.614254              -0.651734          1.370935
# 4            1.553608               0.456551          0.117656
#
#    Terminal_trans_scaled  S.F.Ratio_trans_scaled  perc.alumni_trans_scaled  \
# 0              -0.282374                1.017946                 -0.834712
# 1              -2.248129               -0.435083                 -0.432329
# 2              -1.040711               -0.250216                  0.674492
# 3               1.364588               -1.741872                  1.125798
# 4              -0.687052               -0.515571                 -2.329357
#
#    Expend_trans_scaled  Outstate_Tier_Encoded_scaled  Accept_Rate_scaled
# 0            -0.491183                     -1.098797           -0.032372
# 1             0.552362                      0.358140            0.906193
# 2             0.096393                      0.358140            0.144750
# 3             1.726997                      0.358140            0.612225
# 4             0.637044                     -1.098797            0.064955
#
# [5 rows x 52 columns]

# %% [markdown]
# #### 13. Plot a correlation heatmap of your numeric features
#
# - Include the scaled columns from question 12 along with other columns
# - Which features look most related to `Grad.Rate`?
# - Check and drop highly correlated features

# %%
df_transformed = df.copy()
numeric_df = df_transformed.select_dtypes(include='number')

numeric_df.head()
# Out:
#    Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  P.Undergrad  \
# 0  1660    1232     721         23         52         2885          537
# 1  2186    1924     512         16         29         2683         1227
# 2  1428    1097     336         22         50         1036           99
# 3   417     349     137         60         89          510           63
# 4   193     146      55         16         44          249          869
#
#    Outstate  Room.Board  Books  ...  Outstate_trans_scaled  \
# 0      7440        3300    450  ...              -0.693449
# 1     12280        6450    750  ...               0.556268
# 2     11250        3750    400  ...               0.322011
# 3     12960        5450    450  ...               0.703926
# 4      7560        4120    800  ...              -0.656776
#
#    Books_trans_scaled  Personal_trans_scaled  PhD_trans_scaled  \
# 0           -0.614254               1.271398         -0.290438
# 1            1.302365               0.456551         -2.177364
# 2           -1.038575              -0.068655         -1.263585
# 3           -0.614254              -0.651734          1.370935
# 4            1.553608               0.456551          0.117656
#
#    Terminal_trans_scaled  S.F.Ratio_trans_scaled  perc.alumni_trans_scaled  \
# 0              -0.282374                1.017946                 -0.834712
# 1              -2.248129               -0.435083                 -0.432329
# 2              -1.040711               -0.250216                  0.674492
# 3               1.364588               -1.741872                  1.125798
# 4              -0.687052               -0.515571                 -2.329357
#
#    Expend_trans_scaled  Outstate_Tier_Encoded_scaled  Accept_Rate_scaled
# 0            -0.491183                     -1.098797           -0.032372
# 1             0.552362                      0.358140            0.906193
# 2             0.096393                      0.358140            0.144750
# 3             1.726997                      0.358140            0.612225
# 4             0.637044                     -1.098797            0.064955
#
# [5 rows x 48 columns]

# %%
corr_matrix = numeric_df.corr()

corr_matrix
# Out:
#                                   Apps    Accept    Enroll  Top10perc  \
# Apps                          1.000000  0.943451  0.846822   0.338834
# Accept                        0.943451  1.000000  0.911637   0.192447
# Enroll                        0.846822  0.911637  1.000000   0.181294
# Top10perc                     0.338834  0.192447  0.181294   1.000000
# Top25perc                     0.351640  0.247476  0.226745   0.891995
# F.Undergrad                   0.814491  0.874223  0.964640   0.141289
# P.Undergrad                   0.398264  0.441271  0.513069  -0.105356
# Outstate                      0.050159 -0.025755 -0.155477   0.562331
# Room.Board                    0.164939  0.090899 -0.040232   0.371480
# Books                         0.132559  0.113525  0.112711   0.118858
# Personal                      0.178731  0.200989  0.280929  -0.093316
# PhD                           0.383689  0.350118  0.327084   0.516378
# Terminal                      0.369491  0.337583  0.308274   0.491135
# S.F.Ratio                     0.095633  0.176229  0.237271  -0.384875
# perc.alumni                  -0.090226 -0.159990 -0.180794   0.455485
# Expend                        0.259592  0.124717  0.064169   0.660913
# Grad.Rate                     0.146964  0.066762 -0.022049   0.498118
# Apps_trans                    0.794606  0.774472  0.747884   0.360825
# Accept_trans                  0.771024  0.804449  0.777876   0.269648
# Enroll_trans                  0.734306  0.762798  0.815747   0.241372
# Top10perc_trans               0.297110  0.191417  0.179662   0.948664
# F.Undergrad_trans             0.712560  0.737748  0.790035   0.193083
# P.Undergrad_trans             0.399421  0.462377  0.522659  -0.270109
# Outstate_trans                0.029368 -0.036272 -0.175177   0.520681
# Books_trans                   0.153440  0.131195  0.129697   0.146721
# Personal_trans                0.199707  0.216932  0.291968  -0.095123
# PhD_trans                     0.402026  0.361274  0.333257   0.550503
# Terminal_trans                0.388138  0.347500  0.312149   0.532257
# S.F.Ratio_trans               0.080316  0.166972  0.226729  -0.404754
# perc.alumni_trans            -0.084582 -0.146798 -0.173254   0.436632
# Expend_trans                  0.221717  0.132856  0.045729   0.629753
# Accept_Rate                  -0.392555 -0.175196 -0.152174  -0.478675
# Private_Encoded              -0.432095 -0.475252 -0.567908   0.164132
# Accept_trans_scaled           0.771024  0.804449  0.777876   0.269648
# Enroll_trans_scaled           0.734306  0.762798  0.815747   0.241372
# Top10perc_trans_scaled        0.297110  0.191417  0.179662   0.948664
# F.Undergrad_trans_scaled      0.712560  0.737748  0.790035   0.193083
# P.Undergrad_trans_scaled      0.399421  0.462377  0.522659  -0.270109
# Outstate_trans_scaled         0.029368 -0.036272 -0.175177   0.520681
# Books_trans_scaled            0.153440  0.131195  0.129697   0.146721
# Personal_trans_scaled         0.199707  0.216932  0.291968  -0.095123
# PhD_trans_scaled              0.402026  0.361274  0.333257   0.550503
# Terminal_trans_scaled         0.388138  0.347500  0.312149   0.532257
# S.F.Ratio_trans_scaled        0.080316  0.166972  0.226729  -0.404754
# perc.alumni_trans_scaled     -0.084582 -0.146798 -0.173254   0.436632
# Expend_trans_scaled           0.221717  0.132856  0.045729   0.629753
# Outstate_Tier_Encoded_scaled  0.007794 -0.051759 -0.159778   0.504873
# Accept_Rate_scaled           -0.392555 -0.175196 -0.152174  -0.478675
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Apps                           0.351640     0.814491     0.398264  0.050159
# Accept                         0.247476     0.874223     0.441271 -0.025755
# Enroll                         0.226745     0.964640     0.513069 -0.155477
# Top10perc                      0.891995     0.141289    -0.105356  0.562331
# Top25perc                      1.000000     0.199445    -0.053577  0.489394
# F.Undergrad                    0.199445     1.000000     0.570512 -0.215742
# P.Undergrad                   -0.053577     0.570512     1.000000 -0.253512
# Outstate                       0.489394    -0.215742    -0.253512  1.000000
# Room.Board                     0.331490    -0.068890    -0.061326  0.654256
# Books                          0.115527     0.115550     0.081200  0.038855
# Personal                      -0.080810     0.317200     0.319882 -0.299087
# PhD                            0.530242     0.315497     0.151671  0.365618
# Terminal                       0.524749     0.300019     0.141904  0.407983
# S.F.Ratio                     -0.294629     0.279703     0.232531 -0.554821
# perc.alumni                    0.417864    -0.229462    -0.280792  0.566262
# Expend                         0.527447     0.018652    -0.083568  0.672779
# Grad.Rate                      0.480346    -0.078293    -0.257135  0.573612
# Apps_trans                     0.395466     0.714456     0.383679  0.110619
# Accept_trans                   0.324204     0.742540     0.400515  0.059560
# Enroll_trans                   0.288976     0.782396     0.447755 -0.076446
# Top10perc_trans                0.912686     0.144569    -0.080580  0.541862
# F.Undergrad_trans              0.254013     0.799397     0.493685 -0.133343
# P.Undergrad_trans             -0.193747     0.571084     0.712973 -0.419770
# Outstate_trans                 0.457236    -0.233119    -0.254535  0.988421
# Books_trans                    0.145854     0.132236     0.098612  0.045436
# Personal_trans                -0.080522     0.320858     0.296797 -0.318988
# PhD_trans                      0.554135     0.320848     0.150650  0.407203
# Terminal_trans                 0.550644     0.304274     0.138400  0.442252
# S.F.Ratio_trans               -0.306507     0.269048     0.224910 -0.563349
# perc.alumni_trans              0.409193    -0.223800    -0.286463  0.558348
# Expend_trans                   0.548464     0.005279    -0.104055  0.751518
# Accept_Rate                   -0.434672    -0.155654    -0.092287 -0.240951
# Private_Encoded                0.095752    -0.615561    -0.452088  0.552650
# Accept_trans_scaled            0.324204     0.742540     0.400515  0.059560
# Enroll_trans_scaled            0.288976     0.782396     0.447755 -0.076446
# Top10perc_trans_scaled         0.912686     0.144569    -0.080580  0.541862
# F.Undergrad_trans_scaled       0.254013     0.799397     0.493685 -0.133343
# P.Undergrad_trans_scaled      -0.193747     0.571084     0.712973 -0.419770
# Outstate_trans_scaled          0.457236    -0.233119    -0.254535  0.988421
# Books_trans_scaled             0.145854     0.132236     0.098612  0.045436
# Personal_trans_scaled         -0.080522     0.320858     0.296797 -0.318988
# PhD_trans_scaled               0.554135     0.320848     0.150650  0.407203
# Terminal_trans_scaled          0.550644     0.304274     0.138400  0.442252
# S.F.Ratio_trans_scaled        -0.306507     0.269048     0.224910 -0.563349
# perc.alumni_trans_scaled       0.409193    -0.223800    -0.286463  0.558348
# Expend_trans_scaled            0.548464     0.005279    -0.104055  0.751518
# Outstate_Tier_Encoded_scaled   0.425299    -0.222041    -0.236917  0.917228
# Accept_Rate_scaled            -0.434672    -0.155654    -0.092287 -0.240951
#
#                               Room.Board     Books  ...  \
# Apps                            0.164939  0.132559  ...
# Accept                          0.090899  0.113525  ...
# Enroll                         -0.040232  0.112711  ...
# Top10perc                       0.371480  0.118858  ...
# Top25perc                       0.331490  0.115527  ...
# F.Undergrad                    -0.068890  0.115550  ...
# P.Undergrad                    -0.061326  0.081200  ...
# Outstate                        0.654256  0.038855  ...
# Room.Board                      1.000000  0.127963  ...
# Books                           0.127963  1.000000  ...
# Personal                       -0.199428  0.179295  ...
# PhD                             0.314629  0.026735  ...
# Terminal                        0.374540  0.099955  ...
# S.F.Ratio                      -0.362628 -0.031929  ...
# perc.alumni                     0.272363 -0.040208  ...
# Expend                          0.501739  0.112409  ...
# Grad.Rate                       0.425808  0.000649  ...
# Apps_trans                      0.198115  0.160655  ...
# Accept_trans                    0.142588  0.130453  ...
# Enroll_trans                    0.014317  0.145007  ...
# Top10perc_trans                 0.330780  0.078487  ...
# F.Undergrad_trans               0.004144  0.147666  ...
# P.Undergrad_trans              -0.071574  0.049374  ...
# Outstate_trans                  0.653764  0.029238  ...
# Books_trans                     0.138491  0.943793  ...
# Personal_trans                 -0.208366  0.167617  ...
# PhD_trans                       0.352713  0.076237  ...
# Terminal_trans                  0.399277  0.117569  ...
# S.F.Ratio_trans                -0.374808 -0.038241  ...
# perc.alumni_trans               0.272353 -0.047740  ...
# Expend_trans                    0.572789  0.135843  ...
# Accept_Rate                    -0.310302 -0.174073  ...
# Private_Encoded                 0.340532 -0.018549  ...
# Accept_trans_scaled             0.142588  0.130453  ...
# Enroll_trans_scaled             0.014317  0.145007  ...
# Top10perc_trans_scaled          0.330780  0.078487  ...
# F.Undergrad_trans_scaled        0.004144  0.147666  ...
# P.Undergrad_trans_scaled       -0.071574  0.049374  ...
# Outstate_trans_scaled           0.653764  0.029238  ...
# Books_trans_scaled              0.138491  0.943793  ...
# Personal_trans_scaled          -0.208366  0.167617  ...
# PhD_trans_scaled                0.352713  0.076237  ...
# Terminal_trans_scaled           0.399277  0.117569  ...
# S.F.Ratio_trans_scaled         -0.374808 -0.038241  ...
# perc.alumni_trans_scaled        0.272353 -0.047740  ...
# Expend_trans_scaled             0.572789  0.135843  ...
# Outstate_Tier_Encoded_scaled    0.591122  0.035397  ...
# Accept_Rate_scaled             -0.310302 -0.174073  ...
#
#                               Outstate_trans_scaled  Books_trans_scaled  \
# Apps                                       0.029368            0.153440
# Accept                                    -0.036272            0.131195
# Enroll                                    -0.175177            0.129697
# Top10perc                                  0.520681            0.146721
# Top25perc                                  0.457236            0.145854
# F.Undergrad                               -0.233119            0.132236
# P.Undergrad                               -0.254535            0.098612
# Outstate                                   0.988421            0.045436
# Room.Board                                 0.653764            0.138491
# Books                                      0.029238            0.943793
# Personal                                  -0.291084            0.193220
# PhD                                        0.333002            0.073537
# Terminal                                   0.378239            0.122858
# S.F.Ratio                                 -0.559998           -0.030432
# perc.alumni                                0.551699           -0.017902
# Expend                                     0.630365            0.122854
# Grad.Rate                                  0.569032           -0.005470
# Apps_trans                                 0.068156            0.171496
# Accept_trans                               0.025940            0.140941
# Enroll_trans                              -0.117564            0.153224
# Top10perc_trans                            0.511492            0.118646
# F.Undergrad_trans                         -0.170220            0.158909
# P.Undergrad_trans                         -0.408416            0.057947
# Outstate_trans                             1.000000            0.036302
# Books_trans                                0.036302            1.000000
# Personal_trans                            -0.311566            0.187422
# PhD_trans                                  0.372302            0.111272
# Terminal_trans                             0.407743            0.141007
# S.F.Ratio_trans                           -0.565402           -0.036696
# perc.alumni_trans                          0.551149           -0.022256
# Expend_trans                               0.736715            0.147633
# Accept_Rate                               -0.193301           -0.180034
# Private_Encoded                            0.587627           -0.018053
# Accept_trans_scaled                        0.025940            0.140941
# Enroll_trans_scaled                       -0.117564            0.153224
# Top10perc_trans_scaled                     0.511492            0.118646
# F.Undergrad_trans_scaled                  -0.170220            0.158909
# P.Undergrad_trans_scaled                  -0.408416            0.057947
# Outstate_trans_scaled                      1.000000            0.036302
# Books_trans_scaled                         0.036302            1.000000
# Personal_trans_scaled                     -0.311566            0.187422
# PhD_trans_scaled                           0.372302            0.111272
# Terminal_trans_scaled                      0.407743            0.141007
# S.F.Ratio_trans_scaled                    -0.565402           -0.036696
# perc.alumni_trans_scaled                   0.551149           -0.022256
# Expend_trans_scaled                        0.736715            0.147633
# Outstate_Tier_Encoded_scaled               0.903249            0.037591
# Accept_Rate_scaled                        -0.193301           -0.180034
#
#                               Personal_trans_scaled  PhD_trans_scaled  \
# Apps                                       0.199707          0.402026
# Accept                                     0.216932          0.361274
# Enroll                                     0.291968          0.333257
# Top10perc                                 -0.095123          0.550503
# Top25perc                                 -0.080522          0.554135
# F.Undergrad                                0.320858          0.320848
# P.Undergrad                                0.296797          0.150650
# Outstate                                  -0.318988          0.407203
# Room.Board                                -0.208366          0.352713
# Books                                      0.167617          0.076237
# Personal                                   0.946831         -0.010309
# PhD                                       -0.009149          0.985232
# Terminal                                  -0.036057          0.836389
# S.F.Ratio                                  0.159418         -0.141995
# perc.alumni                               -0.290077          0.242334
# Expend                                    -0.102414          0.466908
# Grad.Rate                                 -0.269853          0.308812
# Apps_trans                                 0.186492          0.514578
# Accept_trans                               0.202311          0.479473
# Enroll_trans                               0.264256          0.419563
# Top10perc_trans                           -0.093329          0.546087
# F.Undergrad_trans                          0.284965          0.393074
# P.Undergrad_trans                          0.343664          0.010151
# Outstate_trans                            -0.311566          0.372302
# Books_trans                                0.187422          0.111272
# Personal_trans                             1.000000         -0.019597
# PhD_trans                                 -0.019597          1.000000
# Terminal_trans                            -0.042994          0.849805
# S.F.Ratio_trans                            0.156867         -0.150090
# perc.alumni_trans                         -0.289943          0.227612
# Expend_trans                              -0.141011          0.514525
# Accept_Rate                                0.003997         -0.334730
# Private_Encoded                           -0.317645         -0.139691
# Accept_trans_scaled                        0.202311          0.479473
# Enroll_trans_scaled                        0.264256          0.419563
# Top10perc_trans_scaled                    -0.093329          0.546087
# F.Undergrad_trans_scaled                   0.284965          0.393074
# P.Undergrad_trans_scaled                   0.343664          0.010151
# Outstate_trans_scaled                     -0.311566          0.372302
# Books_trans_scaled                         0.187422          0.111272
# Personal_trans_scaled                      1.000000         -0.019597
# PhD_trans_scaled                          -0.019597          1.000000
# Terminal_trans_scaled                     -0.042994          0.849805
# S.F.Ratio_trans_scaled                     0.156867         -0.150090
# perc.alumni_trans_scaled                  -0.289943          0.227612
# Expend_trans_scaled                       -0.141011          0.514525
# Outstate_Tier_Encoded_scaled              -0.316285          0.326884
# Accept_Rate_scaled                         0.003997         -0.334730
#
#                               Terminal_trans_scaled  S.F.Ratio_trans_scaled  \
# Apps                                       0.388138                0.080316
# Accept                                     0.347500                0.166972
# Enroll                                     0.312149                0.226729
# Top10perc                                  0.532257               -0.404754
# Top25perc                                  0.550644               -0.306507
# F.Undergrad                                0.304274                0.269048
# P.Undergrad                                0.138400                0.224910
# Outstate                                   0.442252               -0.563349
# Room.Board                                 0.399277               -0.374808
# Books                                      0.117569               -0.038241
# Personal                                  -0.032062                0.131860
# PhD                                        0.823907               -0.105878
# Terminal                                   0.982402               -0.166135
# S.F.Ratio                                 -0.184697                0.994710
# perc.alumni                                0.277765               -0.401604
# Expend                                     0.486538               -0.620014
# Grad.Rate                                  0.310527               -0.310808
# Apps_trans                                 0.493224                0.148778
# Accept_trans                               0.457793                0.196220
# Enroll_trans                               0.393457                0.271822
# Top10perc_trans                            0.519396               -0.377583
# F.Undergrad_trans                          0.369080                0.324902
# P.Undergrad_trans                          0.001818                0.367257
# Outstate_trans                             0.407743               -0.565402
# Books_trans                                0.141007               -0.036696
# Personal_trans                            -0.042994                0.156867
# PhD_trans                                  0.849805               -0.150090
# Terminal_trans                             1.000000               -0.194435
# S.F.Ratio_trans                           -0.194435                1.000000
# perc.alumni_trans                          0.261227               -0.402741
# Expend_trans                               0.542659               -0.671135
# Accept_Rate                               -0.326964                0.130268
# Private_Encoded                           -0.115951               -0.467200
# Accept_trans_scaled                        0.457793                0.196220
# Enroll_trans_scaled                        0.393457                0.271822
# Top10perc_trans_scaled                     0.519396               -0.377583
# F.Undergrad_trans_scaled                   0.369080                0.324902
# P.Undergrad_trans_scaled                   0.001818                0.367257
# Outstate_trans_scaled                      0.407743               -0.565402
# Books_trans_scaled                         0.141007               -0.036696
# Personal_trans_scaled                     -0.042994                0.156867
# PhD_trans_scaled                           0.849805               -0.150090
# Terminal_trans_scaled                      1.000000               -0.194435
# S.F.Ratio_trans_scaled                    -0.194435                1.000000
# perc.alumni_trans_scaled                   0.261227               -0.402741
# Expend_trans_scaled                        0.542659               -0.671135
# Outstate_Tier_Encoded_scaled               0.365742               -0.529865
# Accept_Rate_scaled                        -0.326964                0.130268
#
#                               perc.alumni_trans_scaled  Expend_trans_scaled  \
# Apps                                         -0.084582             0.221717
# Accept                                       -0.146798             0.132856
# Enroll                                       -0.173254             0.045729
# Top10perc                                     0.436632             0.629753
# Top25perc                                     0.409193             0.548464
# F.Undergrad                                  -0.223800             0.005279
# P.Undergrad                                  -0.286463            -0.104055
# Outstate                                      0.558348             0.751518
# Room.Board                                    0.272353             0.572789
# Books                                        -0.047740             0.135843
# Personal                                     -0.286005            -0.134326
# PhD                                           0.219642             0.461406
# Terminal                                      0.255500             0.502790
# S.F.Ratio                                    -0.405778            -0.658693
# perc.alumni                                   0.983746             0.452450
# Expend                                        0.392709             0.849968
# Grad.Rate                                     0.500899             0.417198
# Apps_trans                                   -0.059070             0.219872
# Accept_trans                                 -0.093753             0.159865
# Enroll_trans                                 -0.157842             0.049481
# Top10perc_trans                               0.444476             0.602572
# F.Undergrad_trans                            -0.228852            -0.012016
# P.Undergrad_trans                            -0.469884            -0.308657
# Outstate_trans                                0.551149             0.736715
# Books_trans                                  -0.022256             0.147633
# Personal_trans                               -0.289943            -0.141011
# PhD_trans                                     0.227612             0.514525
# Terminal_trans                                0.261227             0.542659
# S.F.Ratio_trans                              -0.402741            -0.671135
# perc.alumni_trans                             1.000000             0.438956
# Expend_trans                                  0.438956             1.000000
# Accept_Rate                                  -0.103062            -0.318554
# Private_Encoded                               0.423564             0.348161
# Accept_trans_scaled                          -0.093753             0.159865
# Enroll_trans_scaled                          -0.157842             0.049481
# Top10perc_trans_scaled                        0.444476             0.602572
# F.Undergrad_trans_scaled                     -0.228852            -0.012016
# P.Undergrad_trans_scaled                     -0.469884            -0.308657
# Outstate_trans_scaled                         0.551149             0.736715
# Books_trans_scaled                           -0.022256             0.147633
# Personal_trans_scaled                        -0.289943            -0.141011
# PhD_trans_scaled                              0.227612             0.514525
# Terminal_trans_scaled                         0.261227             0.542659
# S.F.Ratio_trans_scaled                       -0.402741            -0.671135
# perc.alumni_trans_scaled                      1.000000             0.438956
# Expend_trans_scaled                           0.438956             1.000000
# Outstate_Tier_Encoded_scaled                  0.531648             0.682646
# Accept_Rate_scaled                           -0.103062            -0.318554
#
#                               Outstate_Tier_Encoded_scaled  Accept_Rate_scaled
# Apps                                              0.007794           -0.392555
# Accept                                           -0.051759           -0.175196
# Enroll                                           -0.159778           -0.152174
# Top10perc                                         0.504873           -0.478675
# Top25perc                                         0.425299           -0.434672
# F.Undergrad                                      -0.222041           -0.155654
# P.Undergrad                                      -0.236917           -0.092287
# Outstate                                          0.917228           -0.240951
# Room.Board                                        0.591122           -0.310302
# Books                                             0.035397           -0.174073
# Personal                                         -0.302489            0.019979
# PhD                                               0.289696           -0.312477
# Terminal                                          0.332786           -0.303800
# S.F.Ratio                                        -0.519307            0.109982
# perc.alumni                                       0.533291           -0.132104
# Expend                                            0.611967           -0.408622
# Grad.Rate                                         0.538930           -0.289299
# Apps_trans                                        0.059252           -0.458520
# Accept_trans                                      0.020219           -0.262581
# Enroll_trans                                     -0.095155           -0.244888
# Top10perc_trans                                   0.490887           -0.377092
# F.Undergrad_trans                                -0.150285           -0.253018
# P.Undergrad_trans                                -0.388001            0.004147
# Outstate_trans                                    0.903249           -0.193301
# Books_trans                                       0.037591           -0.180034
# Personal_trans                                   -0.316285            0.003997
# PhD_trans                                         0.326884           -0.334730
# Terminal_trans                                    0.365742           -0.326964
# S.F.Ratio_trans                                  -0.529865            0.130268
# perc.alumni_trans                                 0.531648           -0.103062
# Expend_trans                                      0.682646           -0.318554
# Accept_Rate                                      -0.171272            1.000000
# Private_Encoded                                   0.538362            0.084990
# Accept_trans_scaled                               0.020219           -0.262581
# Enroll_trans_scaled                              -0.095155           -0.244888
# Top10perc_trans_scaled                            0.490887           -0.377092
# F.Undergrad_trans_scaled                         -0.150285           -0.253018
# P.Undergrad_trans_scaled                         -0.388001            0.004147
# Outstate_trans_scaled                             0.903249           -0.193301
# Books_trans_scaled                                0.037591           -0.180034
# Personal_trans_scaled                            -0.316285            0.003997
# PhD_trans_scaled                                  0.326884           -0.334730
# Terminal_trans_scaled                             0.365742           -0.326964
# S.F.Ratio_trans_scaled                           -0.529865            0.130268
# perc.alumni_trans_scaled                          0.531648           -0.103062
# Expend_trans_scaled                               0.682646           -0.318554
# Outstate_Tier_Encoded_scaled                      1.000000           -0.171272
# Accept_Rate_scaled                               -0.171272            1.000000
#
# [48 rows x 48 columns]

# %%
plt.figure(figsize=(20, 16))

sns.heatmap(
    corr_matrix,
    cmap='coolwarm',
    center=0
)

plt.title('Correlation Heatmap of Numeric Features', fontsize=14)
plt.tight_layout()
plt.show()

# %%
grad_rate_corr = (
    corr_matrix['Grad.Rate']
    .drop('Grad.Rate')
    .sort_values(key=abs, ascending=False)
)

grad_rate_corr.head(10)
# Out:
# Outstate                        0.573612
# Outstate_trans_scaled           0.569032
# Outstate_trans                  0.569032
# Outstate_Tier_Encoded_scaled    0.538930
# perc.alumni_trans               0.500899
# perc.alumni_trans_scaled        0.500899
# Top10perc                       0.498118
# Top10perc_trans                 0.495577
# Top10perc_trans_scaled          0.495577
# perc.alumni                     0.492887
# Name: Grad.Rate, dtype: float64

# %%
absolute_corr = corr_matrix.abs()

upper_triangle = absolute_corr.where(
    np.triu(np.ones(absolute_corr.shape), k=1).astype(bool)
)

# %%
high_corr_pairs = upper_triangle.stack().reset_index()

high_corr_pairs.columns = [
    'Feature_1',
    'Feature_2',
    'Correlation'
]

high_corr_pairs = high_corr_pairs[
    high_corr_pairs['Correlation'] > 0.90
].sort_values(by='Correlation', ascending=False)

high_corr_pairs
# Out:
#                   Feature_1                     Feature_2  Correlation
# 1240         Personal_trans         Personal_trans_scaled     1.000000
# 1387        S.F.Ratio_trans        S.F.Ratio_trans_scaled     1.000000
# 1535            Accept_Rate            Accept_Rate_scaled     1.000000
# 1485           Expend_trans           Expend_trans_scaled     1.000000
# 1436      perc.alumni_trans      perc.alumni_trans_scaled     1.000000
# 946            Enroll_trans           Enroll_trans_scaled     1.000000
# 1044      F.Undergrad_trans      F.Undergrad_trans_scaled     1.000000
# 1093      P.Undergrad_trans      P.Undergrad_trans_scaled     1.000000
# 1338         Terminal_trans         Terminal_trans_scaled     1.000000
# 897            Accept_trans           Accept_trans_scaled     1.000000
# 1142         Outstate_trans         Outstate_trans_scaled     1.000000
# 1191            Books_trans            Books_trans_scaled     1.000000
# 1289              PhD_trans              PhD_trans_scaled     1.000000
# 995         Top10perc_trans        Top10perc_trans_scaled     1.000000
# 667               S.F.Ratio        S.F.Ratio_trans_scaled     0.994710
# 652               S.F.Ratio               S.F.Ratio_trans     0.994710
# 374                Outstate         Outstate_trans_scaled     0.988421
# 359                Outstate                Outstate_trans     0.988421
# 554                     PhD                     PhD_trans     0.985232
# 569                     PhD              PhD_trans_scaled     0.985232
# 701             perc.alumni             perc.alumni_trans     0.983746
# 716             perc.alumni      perc.alumni_trans_scaled     0.983746
# 618                Terminal         Terminal_trans_scaled     0.982402
# 603                Terminal                Terminal_trans     0.982402
# 834              Apps_trans                  Accept_trans     0.976973
# 849              Apps_trans           Accept_trans_scaled     0.976973
# 101                  Enroll                   F.Undergrad     0.964640
# 948            Enroll_trans      F.Undergrad_trans_scaled     0.956356
# 933            Enroll_trans             F.Undergrad_trans     0.956356
# 1668    Enroll_trans_scaled      F.Undergrad_trans_scaled     0.956356
# 1042      F.Undergrad_trans           Enroll_trans_scaled     0.956356
# 179               Top10perc        Top10perc_trans_scaled     0.948664
# 164               Top10perc               Top10perc_trans     0.948664
# 898            Accept_trans           Enroll_trans_scaled     0.948058
# 1618    Accept_trans_scaled           Enroll_trans_scaled     0.948058
# 945            Enroll_trans           Accept_trans_scaled     0.948058
# 883            Accept_trans                  Enroll_trans     0.948058
# 505                Personal                Personal_trans     0.946831
# 520                Personal         Personal_trans_scaled     0.946831
# 456                   Books                   Books_trans     0.943793
# 471                   Books            Books_trans_scaled     0.943793
# 1                      Apps                        Accept     0.943451
# 835              Apps_trans                  Enroll_trans     0.927680
# 850              Apps_trans           Enroll_trans_scaled     0.927680
# 382                Outstate  Outstate_Tier_Encoded_scaled     0.917228
# 227               Top25perc        Top10perc_trans_scaled     0.912686
# 212               Top25perc               Top10perc_trans     0.912686
# 50                   Accept                        Enroll     0.911637
# 885            Accept_trans             F.Undergrad_trans     0.904775
# 900            Accept_trans      F.Undergrad_trans_scaled     0.904775
# 1041      F.Undergrad_trans           Accept_trans_scaled     0.904775
# 1620    Accept_trans_scaled      F.Undergrad_trans_scaled     0.904775
# 1870  Outstate_trans_scaled  Outstate_Tier_Encoded_scaled     0.903249
# 1150         Outstate_trans  Outstate_Tier_Encoded_scaled     0.903249

# %%
columns_to_drop = [
    'Personal_trans',
    'S.F.Ratio_trans',
    'Accept_Rate',
    'Expend_trans',
    'perc.alumni_trans',
    'Enroll_trans',
    'F.Undergrad_trans',
    'P.Undergrad_trans',
    'Terminal_trans',
    'Accept_trans',
    'Outstate_trans',
    'Books_trans',
    'PhD_trans',
    'Top10perc_trans'
]

columns_to_drop
# Out:
# ['Personal_trans',
#  'S.F.Ratio_trans',
#  'Accept_Rate',
#  'Expend_trans',
#  'perc.alumni_trans',
#  'Enroll_trans',
#  'F.Undergrad_trans',
#  'P.Undergrad_trans',
#  'Terminal_trans',
#  'Accept_trans',
#  'Outstate_trans',
#  'Books_trans',
#  'PhD_trans',
#  'Top10perc_trans']

# %%
df_transformed = df_transformed.drop(
    columns=columns_to_drop
)

df_transformed.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  ...  Outstate_trans_scaled  \
# 0         52         2885          537      7440  ...              -0.693449
# 1         29         2683         1227     12280  ...               0.556268
# 2         50         1036           99     11250  ...               0.322011
# 3         89          510           63     12960  ...               0.703926
# 4         44          249          869      7560  ...              -0.656776
#
#    Books_trans_scaled  Personal_trans_scaled  PhD_trans_scaled  \
# 0           -0.614254               1.271398         -0.290438
# 1            1.302365               0.456551         -2.177364
# 2           -1.038575              -0.068655         -1.263585
# 3           -0.614254              -0.651734          1.370935
# 4            1.553608               0.456551          0.117656
#
#    Terminal_trans_scaled  S.F.Ratio_trans_scaled  perc.alumni_trans_scaled  \
# 0              -0.282374                1.017946                 -0.834712
# 1              -2.248129               -0.435083                 -0.432329
# 2              -1.040711               -0.250216                  0.674492
# 3               1.364588               -1.741872                  1.125798
# 4              -0.687052               -0.515571                 -2.329357
#
#    Expend_trans_scaled  Outstate_Tier_Encoded_scaled  Accept_Rate_scaled
# 0            -0.491183                     -1.098797           -0.032372
# 1             0.552362                      0.358140            0.906193
# 2             0.096393                      0.358140            0.144750
# 3             1.726997                      0.358140            0.612225
# 4             0.637044                     -1.098797            0.064955
#
# [5 rows x 38 columns]

# %%
df_transformed.shape
# Out:
# (777, 38)

# %%
df_transformed.columns
# Out:
# Index(['College', 'Private', 'Apps', 'Accept', 'Enroll', 'Top10perc',
#        'Top25perc', 'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board',
#        'Books', 'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni',
#        'Expend', 'Grad.Rate', 'Apps_trans', 'Outstate_Tier',
#        'Outstate_Tier_Encoded', 'Private_Encoded', 'Accept_trans_scaled',
#        'Enroll_trans_scaled', 'Top10perc_trans_scaled',
#        'F.Undergrad_trans_scaled', 'P.Undergrad_trans_scaled',
#        'Outstate_trans_scaled', 'Books_trans_scaled', 'Personal_trans_scaled',
#        'PhD_trans_scaled', 'Terminal_trans_scaled', 'S.F.Ratio_trans_scaled',
#        'perc.alumni_trans_scaled', 'Expend_trans_scaled',
#        'Outstate_Tier_Encoded_scaled', 'Accept_Rate_scaled'],
#       dtype='str')

# %%
# Correlation after dropping highly correlated features

corr_after = df_transformed.select_dtypes(include='number').corr()

plt.figure(figsize=(18, 15))

sns.heatmap(
    corr_after,
    cmap='coolwarm',
    center=0
)

plt.title('Correlation Heatmap After Removing Highly Correlated Features')
plt.tight_layout()
plt.show()

# %%
# Columns to exclude from the heatmap
cols_to_exclude = [
    'Private_Encoded',
    'Outstate_Tier_Encoded',
    'Outstate_Tier_Encoded_scaled',
    'Accept_trans_scaled',
    'Enroll_trans_scaled',
    'Top10perc_trans_scaled',
    'F.Undergrad_trans_scaled',
    'P.Undergrad_trans_scaled',
    'Outstate_trans_scaled',
    'Books_trans_scaled',
    'Personal_trans_scaled',
    'PhD_trans_scaled',
    'Terminal_trans_scaled',
    'S.F.Ratio_trans_scaled',
    'perc.alumni_trans_scaled',
    'Expend_trans_scaled',
    'Accept_Rate_scaled'
]

# Create correlation matrix
corr_after = (
    df_transformed
    .drop(columns=cols_to_exclude)
    .select_dtypes(include='number')
    .corr()
)

# Plot heatmap
plt.figure(figsize=(14,12))

sns.heatmap(
    corr_after,
    cmap='coolwarm',
    center=0,
    annot=True,      # show correlation values
    fmt='.2f',       # 2 decimal places
    square=True,
    linewidths=0.5
)

plt.title('Correlation Heatmap After Feature Selection')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part F: Does the Transformation Help?

# %% [markdown]
# #### 14. Split your data into train and test sets
#
# - Train the model twice: once using the untransformed columns, and once using the transformed versions, so we can see whether the transformation actually improved the fit
# - In both cases, the target will be `Grad.Rate`

# %%
# Your code here 

# Original features
X_original = df.drop(columns=[
    'College',
    'Grad.Rate'
])

# Target
y = df['Grad.Rate']

# Train-test split
X_train_orig, X_test_orig, y_train, y_test = train_test_split(
    X_original,
    y,
    test_size=0.2,
    random_state=42
)


# Original features
X_original = df.drop(columns=[
    'College',
    'Grad.Rate',
    'Private',
    'Outstate_Tier'
]).copy()

# Add encoded versions
X_original['Private_Encoded'] = df['Private'].map({
    'Yes': 1,
    'No': 0
})

X_original['Outstate_Tier_Encoded'] = df['Outstate_Tier'].map({
    'Low': 0,
    'Medium': 1,
    'High': 2
})

# Target
y = df['Grad.Rate']



X_train_orig, X_test_orig, y_train, y_test = train_test_split(
    X_original,
    y,
    test_size=0.2,
    random_state=42
)

# %%
model_original = LinearRegression()

model_original.fit(X_train_orig, y_train)

pred_original = model_original.predict(X_test_orig)

r2_original = r2_score(y_test, pred_original)

print("Original Data R²:", r2_original)
# Out:
# Original Data R²: 0.4025865519052091

# %%
model_transformed = LinearRegression()

model_transformed.fit(X_train_trans, y_train_trans)

pred_transformed = model_transformed.predict(X_test_trans)

r2_transformed = r2_score(y_test_trans, pred_transformed)

print("Transformed Data R²:", r2_transformed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 3
#       1 model_transformed = LinearRegression()
#       2
# ----> 3 model_transformed.fit(X_train_trans, y_train_trans)
#       4
#       5 pred_transformed = model_transformed.predict(X_test_trans)
#       6
#
# NameError: name 'y_train_trans' is not defined

# %% [markdown]
# #### 15. Fit a linear regression using the raw predictors

# %%
untrans_predictors = []

# Your code here

# %% [markdown]
# #### 16. Fit the same model using the log-transformed predictors

# %%
trans_predictors = []

# Your code here

# %% [markdown]
# #### 17. Compare the two R-squared scores
#
# - Is there an improvement in the results?

# %%
# Your code here

# %% [markdown]
# #### 18. Export your cleaned and transformed `DataFrame` to a new CSV file called `college_transformed.csv`

# %%
# Your code here
